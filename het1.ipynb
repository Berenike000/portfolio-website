# %%
a= 1
a
# Out:
# 1

# %%
print("Hello")
def sum_1_to_100():
    return sum(range(1, 101))

print(sum_1_to_100())
# Out:
# Hello
# 5050

# %%
import yfinance as yf

apple_stock = yf.download('AAPL')
print(apple_stock)
# Out:
# C:\Users\Bagi Bereniké\AppData\Local\Temp\ipykernel_18804\3743758152.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple_stock = yf.download('AAPL')
# Failed to get ticker 'AAPL' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\Users\Bagi Bereniké\AppData\Local\Programs\Python\Python312\Lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: SSLError('Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: c:\\Users\\Bagi Bereniké\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\certifi\\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Empty DataFrame
# ...
